# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from scipy.spatial import Rectangle

import pyMOEA
import adm2_run as test_rec

# %%
#%qtconsole

# %% [markdown]
# # Artificial Decision Maker Variant 2
# Tests for ADM2
#
# ## Two Objectives
# ### Achievement scalarizíng function
# #### DTLZ2

# %%
res=test_rec.get_res()
import shelve
db=shelve.open("res.db")
db["res"]=res
db.close()
# Out:
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# ref point [0.0, 0.0]           -> [0.709681, 0.709681]
# ref point [0.709681, 0.0]      -> [0.967679, 0.257998]
# ref point [0.967679, 0.0]      -> [0.999599, 0.031845]
# ref point [0.999599, 0.0]      -> [1.0, 2e-06]
# ref point [1.0, 0.0]           -> [1.0, 2e-06]
# ref point [1.0, 2e-06]         -> [1.0, 4e-06]
# ref point [1.0, 2e-06]         -> [1.0, 4e-06]
# ref point [1.0, 4e-06]         -> [1.0, 6e-06]
# ref point [1.0, 4e-06]         -> [1.0, 4e-06]
# ref point [1.0, 4e-06]         -> [1.0, 5e-06]

# %%
test_rec.plot_res(res)

# %% [markdown]
# ## Three Objectives
# ### Achievement scalarizíng function
# #### DTLZ2

# %%
res_k3=test_rec.get_res(nf=3)
# Out:
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# ref point [ 0.  0.  0.]
# ref point [ 0.58383004  0.          0.        ]
# ref point [ 0.89819957  0.          0.        ]
# ref point [ 0.89819957  0.          0.09374897]
# ref point [ 0.98183856  0.          0.09374897]
# New PO point [0.9943299172262896, 0.010137993348009815, 0.10624031255169936] out of bounds
#      For ref [ 0.98183856  0.          0.09374897]
