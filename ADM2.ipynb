# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from scipy.spatial import Rectangle
import shelve

import pyMOEA
import adm2_run
import adm2_run as test_rec

# To have console for playing around uncomment
#%qtconsole
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-578925d80f88> in <module>()
#       6 import shelve
#       7
# ----> 8 import pyMOEA
#       9 import adm2_run
#      10 import adm2_run as test_rec
#
# D:\JYU\iADM\pyMOEA.py in <module>()
#      68     jnius_config.add_classpath(os.path.join(moea_path, 'lib', d))
#      69
# ---> 70 from jnius import autoclass, cast, JavaException
#      71
#      72         # jnius_config.add_classpath(*moea_clspath)
#
# d:\local\opt\Miniconda3\envs\iADM\lib\site-packages\jnius\__init__.py in <module>()
#      10 __version__ = '1.1-dev'
#      11
# ---> 12 from .jnius import *
#      13 from .reflect import *
#      14
#
# ImportError: DLL load failed: The specified module could not be found.

# %% [markdown]
# # Artificial Decision Maker Variant 2
# Tests for ADM2
#
# ## Two Objectives
# ### DTLZ2

# %%
res_2k=[]
for uf_n in range(3):
    res_2k.append(adm2_run.get_res(nf=2,uf_n=uf_n,max_iter=50,problem="DTLZ2"))
adm2_run.show_mds(res_2k,problem="DTLZ2")

for y,r in enumerate(res):
    plot.title("UFC %i"%i)
    plot_res(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3b92a3672432> in <module>()
#       5
#       6 for y,r in enumerate(res):
# ----> 7     plot.title("UFC %i"%i)
#       8     plot_res(r)
#
# NameError: name 'plot' is not defined

# %% [markdown]
# ## Three Objectives
# ### DTLZ2

# %%
res_3k=[]
for uf_n in range(3):
    res_3k.append(adm2_run.get_res(nf=3,uf_n=uf_n,max_iter=50,problem="DTLZ2"))
adm2_run.show_mds(res_3k,problem="DTLZ2")
# Out:
# Could not generate new refpoint from PO point [0.4113624526610741, 0.7639603802122987, 0.5007681269417997]
# Could not generate new refpoint from PO point [0.4098907952506525, 0.765854615262081, 0.5004959880663186]
# Could not generate new refpoint from PO point [0.4988698626269588, 0.7648508685236235, 0.412377604907537]

# %%
# To see the PO and reference poits uncomment these
# print res_3k[0][3][0]    # PO Points
# print res_3k[0][3][1]    # Reference points

# %% [markdown]
# ## Four Objectives
# ### DTLZ2

# %%
res_4k=[]
for uf_n in range(3):
    res_4k.append(adm2_run.get_res(nf=4,uf_n=uf_n))
adm2_run.show_mds(res_4k,problem="DTLZ2")
# Out:
# Could not generate new refpoint from PO point [0.7479998317991802, 0.5677324513934683, 0.2475100766178264, 0.2459218406668068]
# Could not generate new refpoint from PO point [0.7499382116196668, 0.24538306028690401, 0.570129712653626, 0.2453830547902667]
# Could not generate new refpoint from PO point [0.567933205082161, 0.24655214437963, 0.7509513949300116, 0.24757116582596264]

# %% [markdown]
# ### DTLZ2 5 obj

# %%
res_5k=[]
for uf_n in range(3):
    res_3k.append(adm2_run.get_res(nf=5,uf_n=uf_n))
adm2_run.show_mds(res_5k,problem="DTLZ2")
# Out:
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# New PO point [0.5720791086264582, 0.2515585171591045, 0.2515520486795423, 0.6975556380662313, 0.25169144892472706] out of bounds
#      For ref [ 0.32038766  0.          0.          0.44595724  0.        ]
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# New PO point [0.2517082713078598, 0.7057389962004575, 0.2544532101970089, 0.5683415050711579, 0.24967674775282256] out of bounds
#      For ref [ 0.          0.45137212  0.          0.31388829  0.        ]
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# New PO point [0.24516790903732857, 0.5660878725580385, 0.705379796834007, 0.25420559002291343, 0.2541216923903163] out of bounds
#      For ref [ 0.          0.31188228  0.45120738  0.          0.        ]

# %%
db=shelve.open("res.db")
try:
    res_k4=db["res_k4"]
except KeyError:
    res_k4=adm2_run.get_res(nf=4);
    db["res_k4"]=res_k4
finally:
    db.close()

# %%
# Two ten runs and append to res_3.db

import shelve
db=shelve.open("res_3.db")
try:
    res=db["res"]
except KeyError:
    print "Empty res"
    res=[]
if not len(res):
    db["res"]=[]

for i in range(10):
    print "Running %i"%i
    res.append(adm2_run.get_res(nf=3,problem='DTLZ2'))
db["res"]=res
db.close()
# Out:
# Running 0
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# Running 1
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# Running 2
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# Running 3
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# Running 4
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# Running 5
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# Running 6
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# Running 7
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# Running 8
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# Running 9
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1

# %% [markdown]
# ### DTLZ2 3 obj, 50 iterations

# %%
# %matplotlib inline
reload(pyMOEA)
reload(adm2_run)
res_50=[]

uf=["CES","Cobb-Douglas","TOPSIS"]

for uf_n in range(3):
    res_50.append(adm2_run.get_res(nf=3,problem='DTLZ2',max_iter=50,uf_n=uf_n))

fig, axes = plt.subplots(nrows=2, ncols=2)
fig.suptitle("DTLZ2 3 obj")

k=lambda i,j:adm2_run.plot_mds(axes[i][j],res_50[i*(j+1)+(j+1)][3][0]);

try:
    [[k(i,j) for i in range(2)]for j in range(2)];
except IndexError:
    pass
fig.savefig("DTLZ2_3k.png",dpi=200)
# Out:
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.suptitle("DTLZ2 3 obj")

k=lambda i,j:adm2_run.plot_mds(axes[i][j],res_50[i*(j+1)+(j+1)][3][0]);

try:
    [[k(i,j) for i in range(2)]for j in range(2)];
except IndexError:
    pass
fig.savefig("DTLZ2_3k.png",dpi=200)

# %%
fig.savefig("results20.png")

# %%
import adm2_run
res=adm2_run.get_res(nf=3)
# Out:
# AMD2 Solving: ('ACH_solution', 'DTLZ2'):1

# %%
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\MyTemp\local\share\opt\Miniconda3\envs\research\lib\site-packages\IPython\core\magics\pylab.py:161: UserWarning: pylab import has clobbered these variables: ['Rectangle']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
